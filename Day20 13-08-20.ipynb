# %%
import pandas as pd

# %%
data=pd.read_csv('employees.csv',parse_dates=['Start Date','Last Login Time'])
data['Gender']=data['Gender'].astype('category')
data['Senior Management']=data['Senior Management'].astype('bool')
data.sort_values('First Name',inplace=True)
data
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 101      Aaron    Male 2012-02-17 2022-08-13 10:20:00   61602   11.849
# 327      Aaron    Male 1994-01-29 2022-08-13 18:48:00   58755    5.097
# 440      Aaron    Male 1990-07-22 2022-08-13 14:53:00   52119   11.343
# 937      Aaron     NaN 1986-01-22 2022-08-13 19:39:00   63126   18.424
# 137       Adam    Male 2011-05-21 2022-08-13 01:45:00   95327   15.120
# ..         ...     ...        ...                 ...     ...      ...
# 902        NaN    Male 2001-05-23 2022-08-13 19:52:00  103877    6.322
# 925        NaN  Female 2000-08-23 2022-08-13 16:19:00   95866   19.388
# 946        NaN  Female 1985-09-15 2022-08-13 01:50:00  133472   16.941
# 947        NaN    Male 2012-07-30 2022-08-13 15:07:00  107351    5.329
# 951        NaN  Female 2010-09-14 2022-08-13 05:19:00  143638    9.662
#
#      Senior Management             Team
# 101               True        Marketing
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1000 entries, 101 to 951
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         933 non-null    object
#  1   Gender             855 non-null    category
#  2   Start Date         1000 non-null   datetime64[ns]
#  3   Last Login Time    1000 non-null   datetime64[ns]
#  4   Salary             1000 non-null   int64
#  5   Bonus %            1000 non-null   float64
#  6   Senior Management  1000 non-null   bool
#  7   Team               957 non-null    object
# dtypes: bool(1), category(1), datetime64[ns](2), float64(1), int64(1), object(2)
# memory usage: 56.8+ KB

# %%
len(data)
# Out:
# 1000

# %%
len(data.drop_duplicates())
# Out:
# 1000

# %%
len(data.drop_duplicates(subset=['First Name'],keep='first'))
# Out:
# 201

# %%
len(data.drop_duplicates(subset=['First Name','Team'],keep='first'))
# Out:
# 769

# %%
data.drop_duplicates(subset=['First Name','Team'],inplace=True)
data
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 101      Aaron    Male 2012-02-17 2022-08-13 10:20:00   61602   11.849
# 440      Aaron    Male 1990-07-22 2022-08-13 14:53:00   52119   11.343
# 137       Adam    Male 2011-05-21 2022-08-13 01:45:00   95327   15.120
# 141       Adam    Male 1990-12-24 2022-08-13 20:57:00  110194   14.727
# 302       Adam    Male 2007-07-05 2022-08-13 11:59:00   71276    5.027
# ..         ...     ...        ...                 ...     ...      ...
# 149        NaN  Female 2014-08-17 2022-08-13 14:00:00   86230    8.578
# 157        NaN  Female 2005-07-27 2022-08-13 08:32:00   79536   14.443
# 269        NaN  Female 1992-08-02 2022-08-13 20:35:00  145316   18.517
# 329        NaN    Male 2010-01-27 2022-08-13 02:57:00   87760   14.987
# 481        NaN  Female 2013-04-27 2022-08-13 06:40:00   93847    1.085
#
#      Senior Management                  Team
# 101               True             Marketing
# ...

# %%
jb=pd.read_csv('jamesbond.csv')
jb
# Out:
#                                Film  Year           Actor            Director  \
# 0                            Dr. No  1962    Sean Connery       Terence Young
# 1             From Russia with Love  1963    Sean Connery       Terence Young
# 2                        Goldfinger  1964    Sean Connery        Guy Hamilton
# 3                       Thunderball  1965    Sean Connery       Terence Young
# 4                     Casino Royale  1967     David Niven          Ken Hughes
# 5               You Only Live Twice  1967    Sean Connery       Lewis Gilbert
# 6   On Her Majesty's Secret Service  1969  George Lazenby       Peter R. Hunt
# 7              Diamonds Are Forever  1971    Sean Connery        Guy Hamilton
# 8                  Live and Let Die  1973     Roger Moore        Guy Hamilton
# 9       The Man with the Golden Gun  1974     Roger Moore        Guy Hamilton
# 10             The Spy Who Loved Me  1977     Roger Moore       Lewis Gilbert
# ...

# %%
len(jb)
# Out:
# 26

# %%
jb.set_index('Film',inplace=True)

# %%
jb
# Out:
#                                  Year           Actor            Director  \
# Film
# Dr. No                           1962    Sean Connery       Terence Young
# From Russia with Love            1963    Sean Connery       Terence Young
# Goldfinger                       1964    Sean Connery        Guy Hamilton
# Thunderball                      1965    Sean Connery       Terence Young
# Casino Royale                    1967     David Niven          Ken Hughes
# You Only Live Twice              1967    Sean Connery       Lewis Gilbert
# On Her Majesty's Secret Service  1969  George Lazenby       Peter R. Hunt
# Diamonds Are Forever             1971    Sean Connery        Guy Hamilton
# Live and Let Die                 1973     Roger Moore        Guy Hamilton
# The Man with the Golden Gun      1974     Roger Moore        Guy Hamilton
# The Spy Who Loved Me             1977     Roger Moore       Lewis Gilbert
# Moonraker                        1979     Roger Moore       Lewis Gilbert
# ...

# %%
jb.set_index('Year',inplace=True)
jb
# Out:
#                Actor            Director  Box Office  Budget  \
# Year
# 1962    Sean Connery       Terence Young       448.8     7.0
# 1963    Sean Connery       Terence Young       543.8    12.6
# 1964    Sean Connery        Guy Hamilton       820.4    18.6
# 1965    Sean Connery       Terence Young       848.1    41.9
# 1967     David Niven          Ken Hughes       315.0    85.0
# 1967    Sean Connery       Lewis Gilbert       514.2    59.9
# 1969  George Lazenby       Peter R. Hunt       291.5    37.3
# 1971    Sean Connery        Guy Hamilton       442.5    34.7
# 1973     Roger Moore        Guy Hamilton       460.3    30.8
# 1974     Roger Moore        Guy Hamilton       334.0    27.7
# 1977     Roger Moore       Lewis Gilbert       533.0    45.1
# 1979     Roger Moore       Lewis Gilbert       535.0    91.5
# 1981     Roger Moore           John Glen       449.4    60.2
# 1983    Sean Connery      Irvin Kershner       380.0    86.0
# ...

# %%
jb.reset_index(inplace=True)

# %%
jb


#shi se column ni aane pe dubara data call kiya gya
# Out:
#     Year           Actor            Director  Box Office  Budget  \
# 0   1962    Sean Connery       Terence Young       448.8     7.0
# 1   1963    Sean Connery       Terence Young       543.8    12.6
# 2   1964    Sean Connery        Guy Hamilton       820.4    18.6
# 3   1965    Sean Connery       Terence Young       848.1    41.9
# 4   1967     David Niven          Ken Hughes       315.0    85.0
# 5   1967    Sean Connery       Lewis Gilbert       514.2    59.9
# 6   1969  George Lazenby       Peter R. Hunt       291.5    37.3
# 7   1971    Sean Connery        Guy Hamilton       442.5    34.7
# 8   1973     Roger Moore        Guy Hamilton       460.3    30.8
# 9   1974     Roger Moore        Guy Hamilton       334.0    27.7
# 10  1977     Roger Moore       Lewis Gilbert       533.0    45.1
# 11  1979     Roger Moore       Lewis Gilbert       535.0    91.5
# 12  1981     Roger Moore           John Glen       449.4    60.2
# ...

# %%
data=pd.read_csv('jamesbond.csv',index_col='Film')
data
# Out:
#                                  Year           Actor            Director  \
# Film
# Dr. No                           1962    Sean Connery       Terence Young
# From Russia with Love            1963    Sean Connery       Terence Young
# Goldfinger                       1964    Sean Connery        Guy Hamilton
# Thunderball                      1965    Sean Connery       Terence Young
# Casino Royale                    1967     David Niven          Ken Hughes
# You Only Live Twice              1967    Sean Connery       Lewis Gilbert
# On Her Majesty's Secret Service  1969  George Lazenby       Peter R. Hunt
# Diamonds Are Forever             1971    Sean Connery        Guy Hamilton
# Live and Let Die                 1973     Roger Moore        Guy Hamilton
# The Man with the Golden Gun      1974     Roger Moore        Guy Hamilton
# The Spy Who Loved Me             1977     Roger Moore       Lewis Gilbert
# Moonraker                        1979     Roger Moore       Lewis Gilbert
# ...

# %%
data.sort_index(inplace=True)

# %%
data
# Out:
#                                  Year           Actor            Director  \
# Film
# A View to a Kill                 1985     Roger Moore           John Glen
# Casino Royale                    2006    Daniel Craig     Martin Campbell
# Casino Royale                    1967     David Niven          Ken Hughes
# Diamonds Are Forever             1971    Sean Connery        Guy Hamilton
# Die Another Day                  2002  Pierce Brosnan        Lee Tamahori
# Dr. No                           1962    Sean Connery       Terence Young
# For Your Eyes Only               1981     Roger Moore           John Glen
# From Russia with Love            1963    Sean Connery       Terence Young
# GoldenEye                        1995  Pierce Brosnan     Martin Campbell
# Goldfinger                       1964    Sean Connery        Guy Hamilton
# Licence to Kill                  1989  Timothy Dalton           John Glen
# Live and Let Die                 1973     Roger Moore        Guy Hamilton
# ...

# %%
#loc==> location
#iloc--->index location
data.loc['Thunderball']
# Out:
# Year                          1965
# Actor                 Sean Connery
# Director             Terence Young
# Box Office                   848.1
# Budget                        41.9
# Bond Actor Salary              4.7
# Name: Thunderball, dtype: object

# %%
data.loc[['Thunderball','Tomorrow Never Dies']]
# Out:
#                      Year           Actor            Director  Box Office  \
# Film
# Thunderball          1965    Sean Connery       Terence Young       848.1
# Tomorrow Never Dies  1997  Pierce Brosnan  Roger Spottiswoode       463.2
#
#                      Budget  Bond Actor Salary
# Film
# Thunderball            41.9                4.7
# Tomorrow Never Dies   133.9               10.0

# %%
data.loc['Dr. No':'Octopussy']
# Out:
#                        Year           Actor         Director  Box Office  \
# Film
# Dr. No                 1962    Sean Connery    Terence Young       448.8
# For Your Eyes Only     1981     Roger Moore        John Glen       449.4
# From Russia with Love  1963    Sean Connery    Terence Young       543.8
# GoldenEye              1995  Pierce Brosnan  Martin Campbell       518.5
# Goldfinger             1964    Sean Connery     Guy Hamilton       820.4
# Licence to Kill        1989  Timothy Dalton        John Glen       250.9
# Live and Let Die       1973     Roger Moore     Guy Hamilton       460.3
# Moonraker              1979     Roger Moore    Lewis Gilbert       535.0
# Never Say Never Again  1983    Sean Connery   Irvin Kershner       380.0
# Octopussy              1983     Roger Moore        John Glen       373.8
#
#                        Budget  Bond Actor Salary
# Film
# Dr. No                    7.0                0.6
# For Your Eyes Only       60.2                NaN
# ...

# %%
'Octopussy' in data.index
# Out:
# True

# %%
'bold' in data.index
# Out:
# False

# %%
data=pd.read_csv('jamesbond.csv')
data
# Out:
#                                Film  Year           Actor            Director  \
# 0                            Dr. No  1962    Sean Connery       Terence Young
# 1             From Russia with Love  1963    Sean Connery       Terence Young
# 2                        Goldfinger  1964    Sean Connery        Guy Hamilton
# 3                       Thunderball  1965    Sean Connery       Terence Young
# 4                     Casino Royale  1967     David Niven          Ken Hughes
# 5               You Only Live Twice  1967    Sean Connery       Lewis Gilbert
# 6   On Her Majesty's Secret Service  1969  George Lazenby       Peter R. Hunt
# 7              Diamonds Are Forever  1971    Sean Connery        Guy Hamilton
# 8                  Live and Let Die  1973     Roger Moore        Guy Hamilton
# 9       The Man with the Golden Gun  1974     Roger Moore        Guy Hamilton
# 10             The Spy Who Loved Me  1977     Roger Moore       Lewis Gilbert
# ...

# %%
data.loc[14]
# Out:
# Film                   Octopussy
# Year                        1983
# Actor                Roger Moore
# Director               John Glen
# Box Office                 373.8
# Budget                      53.9
# Bond Actor Salary            7.8
# Name: 14, dtype: object

# %%
data.iloc[14]
# Out:
# Film                   Octopussy
# Year                        1983
# Actor                Roger Moore
# Director               John Glen
# Box Office                 373.8
# Budget                      53.9
# Bond Actor Salary            7.8
# Name: 14, dtype: object

# %%
data.iloc[[15,23,25]]
# Out:
#                  Film  Year         Actor      Director  Box Office  Budget  \
# 15   A View to a Kill  1985   Roger Moore     John Glen       275.2    54.5
# 23  Quantum of Solace  2008  Daniel Craig  Marc Forster       514.2   181.4
# 25            Spectre  2015  Daniel Craig    Sam Mendes       726.7   206.3
#
#     Bond Actor Salary
# 15                9.1
# 23                8.1
# 25                NaN

# %%
data.iloc[4:7]
# Out:
#                               Film  Year           Actor       Director  \
# 4                    Casino Royale  1967     David Niven     Ken Hughes
# 5              You Only Live Twice  1967    Sean Connery  Lewis Gilbert
# 6  On Her Majesty's Secret Service  1969  George Lazenby  Peter R. Hunt
#
#    Box Office  Budget  Bond Actor Salary
# 4       315.0    85.0                NaN
# 5       514.2    59.9                4.4
# 6       291.5    37.3                0.6

# %%
data.iloc[6:]
# Out:
#                                Film  Year           Actor            Director  \
# 6   On Her Majesty's Secret Service  1969  George Lazenby       Peter R. Hunt
# 7              Diamonds Are Forever  1971    Sean Connery        Guy Hamilton
# 8                  Live and Let Die  1973     Roger Moore        Guy Hamilton
# 9       The Man with the Golden Gun  1974     Roger Moore        Guy Hamilton
# 10             The Spy Who Loved Me  1977     Roger Moore       Lewis Gilbert
# 11                        Moonraker  1979     Roger Moore       Lewis Gilbert
# 12               For Your Eyes Only  1981     Roger Moore           John Glen
# 13            Never Say Never Again  1983    Sean Connery      Irvin Kershner
# 14                        Octopussy  1983     Roger Moore           John Glen
# 15                 A View to a Kill  1985     Roger Moore           John Glen
# 16             The Living Daylights  1987  Timothy Dalton           John Glen
# ...

# %%
data.iloc[:8]
# Out:
#                               Film  Year           Actor       Director  \
# 0                           Dr. No  1962    Sean Connery  Terence Young
# 1            From Russia with Love  1963    Sean Connery  Terence Young
# 2                       Goldfinger  1964    Sean Connery   Guy Hamilton
# 3                      Thunderball  1965    Sean Connery  Terence Young
# 4                    Casino Royale  1967     David Niven     Ken Hughes
# 5              You Only Live Twice  1967    Sean Connery  Lewis Gilbert
# 6  On Her Majesty's Secret Service  1969  George Lazenby  Peter R. Hunt
# 7             Diamonds Are Forever  1971    Sean Connery   Guy Hamilton
#
#    Box Office  Budget  Bond Actor Salary
# 0       448.8     7.0                0.6
# 1       543.8    12.6                1.6
# 2       820.4    18.6                3.2
# 3       848.1    41.9                4.7
# 4       315.0    85.0                NaN
# 5       514.2    59.9                4.4
# ...

# %%
data.loc['Dr. No']
data.iloc[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [59], in <cell line: 1>()
# ----> 1 data.loc['Dr. No']
#       2 data.iloc[0]
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py:967, in _LocationIndexer.__getitem__(self, key)
#     964 axis = self.axis or 0
#     966 maybe_callable = com.apply_if_callable(key, self.obj)
# --> 967 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py:1202, in _LocIndexer._getitem_axis(self, key, axis)
#    1200 # fall thru to straight lookup
#    1201 self._validate_key(key, axis)
# -> 1202 return self._get_label(key, axis=axis)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py:1153, in _LocIndexer._get_label(self, label, axis)
#    1151 def _get_label(self, label, axis: int):
# ...

# %%
import pandas as pd

bond  = pd.read_csv("jamesbond.csv", index_col="Film")
bond.sort_index(inplace=True)
bond.head()
# Out:
#                       Year           Actor         Director  Box Office  \
# Film
# A View to a Kill      1985     Roger Moore        John Glen       275.2
# Casino Royale         2006    Daniel Craig  Martin Campbell       581.5
# Casino Royale         1967     David Niven       Ken Hughes       315.0
# Diamonds Are Forever  1971    Sean Connery     Guy Hamilton       442.5
# Die Another Day       2002  Pierce Brosnan     Lee Tamahori       465.4
#
#                       Budget  Bond Actor Salary
# Film
# A View to a Kill        54.5                9.1
# Casino Royale          145.3                3.3
# Casino Royale           85.0                NaN
# Diamonds Are Forever    34.7                5.8
# Die Another Day        154.2               17.9

# %%
bond.loc["Moonraker","Actor"]
# Out:
# 'Roger Moore'

# %%
bond.loc["Moonraker","Director"]
# Out:
# 'Lewis Gilbert'

# %%
bond.loc["Moonraker","Actor":"Budget"]
# Out:
# Actor           Roger Moore
# Director      Lewis Gilbert
# Box Office            535.0
# Budget                 91.5
# Name: Moonraker, dtype: object

# %%
bond.loc["Moonraker",["Year","Director","Budget"]]
# Out:
# Year                 1979
# Director    Lewis Gilbert
# Budget               91.5
# Name: Moonraker, dtype: object

# %%
bond.iloc[14, 2]
# Out:
# 'John Glen'

# %%
bond.iloc[14, 2:3]
# Out:
# Director    John Glen
# Name: Octopussy, dtype: object

# %%
bond.iloc[14, [5,3,2]]
# Out:
# Bond Actor Salary          7.8
# Box Office               373.8
# Director             John Glen
# Name: Octopussy, dtype: object

# %%
mask=bond['Actor']=='Sean Connery'
bond[mask]
# Out:
#                        Year         Actor        Director  Box Office  Budget  \
# Film
# Diamonds Are Forever   1971  Sean Connery    Guy Hamilton       442.5    34.7
# Dr. No                 1962  Sean Connery   Terence Young       448.8     7.0
# From Russia with Love  1963  Sean Connery   Terence Young       543.8    12.6
# Goldfinger             1964  Sean Connery    Guy Hamilton       820.4    18.6
# Never Say Never Again  1983  Sean Connery  Irvin Kershner       380.0    86.0
# Thunderball            1965  Sean Connery   Terence Young       848.1    41.9
# You Only Live Twice    1967  Sean Connery   Lewis Gilbert       514.2    59.9
#
#                        Bond Actor Salary
# Film
# Diamonds Are Forever                 5.8
# Dr. No                               0.6
# From Russia with Love                1.6
# Goldfinger                           3.2
# Never Say Never Again                NaN
# Thunderball                          4.7
# ...

# %%
bond[mask]['Actor']=='Sir Sean Connery'
# Out:
# Film
# Diamonds Are Forever     False
# Dr. No                   False
# From Russia with Love    False
# Goldfinger               False
# Never Say Never Again    False
# Thunderball              False
# You Only Live Twice      False
# Name: Actor, dtype: bool

# %%
bond[mask]['Actor']='Sir Sean Connery'


#warning ke sath ignore kr diya, nam change ni kiya hai
# Out:
# /var/folders/x0/m85x0zv10gl3rp8t6vmzg8gm0000gn/T/ipykernel_17192/2293823692.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bond[mask]['Actor']='Sir Sean Connery'

# %%
bond
# Out:
#                                  Year           Actor            Director  \
# Film
# A View to a Kill                 1985     Roger Moore           John Glen
# Casino Royale                    2006    Daniel Craig     Martin Campbell
# Casino Royale                    1967     David Niven          Ken Hughes
# Diamonds Are Forever             1971    Sean Connery        Guy Hamilton
# Die Another Day                  2002  Pierce Brosnan        Lee Tamahori
# Dr. No                           1962    Sean Connery       Terence Young
# For Your Eyes Only               1981     Roger Moore           John Glen
# From Russia with Love            1963    Sean Connery       Terence Young
# GoldenEye                        1995  Pierce Brosnan     Martin Campbell
# Goldfinger                       1964    Sean Connery        Guy Hamilton
# Licence to Kill                  1989  Timothy Dalton           John Glen
# Live and Let Die                 1973     Roger Moore        Guy Hamilton
# ...

# %%
bnd=bond[mask]
bnd['Actor']='Sir Sean Connery'
bnd
# Out:
# /var/folders/x0/m85x0zv10gl3rp8t6vmzg8gm0000gn/T/ipykernel_17192/320565074.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bnd['Actor']='Sir Sean Connery'
#                        Year             Actor        Director  Box Office  \
# Film
# Diamonds Are Forever   1971  Sir Sean Connery    Guy Hamilton       442.5
# Dr. No                 1962  Sir Sean Connery   Terence Young       448.8
# From Russia with Love  1963  Sir Sean Connery   Terence Young       543.8
# Goldfinger             1964  Sir Sean Connery    Guy Hamilton       820.4
# Never Say Never Again  1983  Sir Sean Connery  Irvin Kershner       380.0
# Thunderball            1965  Sir Sean Connery   Terence Young       848.1
# ...
