# %%
with open ('test.txt','r') as f:
    x=[]
    y=[]
    data1=f.readlines()

    for col in data1:
        x.append(col[0])
        y.append(col[2])
    
print(x)

print(y)
# Out:
# ['1', '2', '3', '4', '5', '6']
# ['1', '1', '1', '5', '6', '7']

# %%
#csv(comma seperated value)
import csv
x=[]
y=[]
with open('test.txt','r') as f:
    data1=csv.reader(f)
    for col in data1:
        x.append(col[0])
        y.append(col[1])
        
print(x)
print(y)
# Out:
# ['1', '2', '3', '4', '5', '6']
# ['11', '12', '13', '51', '61', '71']

# %%
import matplotlib.pyplot as plt
x=[1,2,3,4,5,6,7]
y=[3,6,2,8,4,8,1]
#plot
plt.plot(x,y)
plt.xlabel('harsh')
plt.ylabel('muskaan')
plt.title('aradhana')
plt.show()

# %%
import matplotlib.pyplot as plt
x=[1,2,3,4,5,6,7]
y=[3,6,2,8,4,8,1]
#plot
plt.plot(x,y,'r',marker='s')
plt.xlabel('harsh')
plt.ylabel('muskaan')
plt.title('aradhana')
plt.show()

# %%
import matplotlib.pyplot as plt
x=[1,2,3,4,5,6,7]
y=[3,6,2,8,4,8,1]
#plot
plt.plot(x,y,'k',marker='s')
plt.xlabel('harsh')
plt.ylabel('muskaan')
plt.title('aradhana')
plt.show()

# %%
import matplotlib.pyplot as plt
x=[1,2,3,4,5,6,7]
y=[3,6,2,8,4,8,1]
#plot
plt.plot(x,y,'--')
plt.xlabel('harsh')
plt.ylabel('muskaan')
plt.title('aradhana')
plt.show()
